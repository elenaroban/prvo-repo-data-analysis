# %%
import pandas as pd

# %% [markdown]
# * Series = isto kako kolona vo database table
# * Dataframe = isto kako tabela vo databese

# %%
# DataFrame from Dictionary
x_dict = {
    "Ime":["Nenad", "Andrej", "Angela", "Beti"],
    "Email":["mail1@gmail.com", "mail2@gmail.com", "mail3@gmail.com","mail4@gmail.com"],
    "Godini":[20,21,23,24],
    "Pol":["M", "M", "F", "F"]
}
df_form_dict = pd.DataFrame(x_dict)
df_form_dict
# Out:
#       Ime            Email  Godini Pol
# 0   Nenad  mail1@gmail.com      20   M
# 1  Andrej  mail2@gmail.com      21   M
# 2  Angela  mail3@gmail.com      23   F
# 3    Beti  mail4@gmail.com      24   F

# %%
x_list = [
    {"Ime":"Nenad", "Email": "mail1@example.com", "Godini": 20, "Pol": "M"},
    {"Ime":"Andrej", "Email": "mail2@example.com", "Godini": 21, "Pol": "M"},
    {"Ime":"Angela", "Email": "mail3@example.com", "Godini": 22, "Pol": "F"},
    {"Ime":"Beti", "Email": "mail4@example.com", "Godini": 23, "Pol": "F"}
]
df_from_list = pd.DataFrame(x_list)
df_from_list
# Out:
#       Ime              Email  Godini Pol
# 0   Nenad  mail1@example.com      20   M
# 1  Andrej  mail2@example.com      21   M
# 2  Angela  mail3@example.com      22   F
# 3    Beti  mail4@example.com      23   F

# %%
#df_from_csv = pd.read_csv('Titanic-Dataset.csv', encoding='utf-8', usecols= ['PassengerId','Name','Sex','Age'])
df_from_csv = pd.read_csv('Titanic-Dataset.csv', encoding='utf-8')
#df_from_csv

# %%
df_from_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df_from_csv.head() #ako se prazni zagradite prvite 5 redovi
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df_from_csv.tail() #ako se prazni zagradite poslednite 5 redovi
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df_from_json = pd.read_json('datasets/titanic-data.json', encoding= 'utf-8')
df_from_json
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df = pd.read_csv ('Popular_Spotify_Songs.csv', encoding='ISO-8859-1')
df
# Out:
#                               track_name      artist(s)_name  artist_count  \
# 0    Seven (feat. Latto) (Explicit Ver.)    Latto, Jung Kook             2
# 1                                   LALA         Myke Towers             1
# 2                                vampire      Olivia Rodrigo             1
# 3                           Cruel Summer        Taylor Swift             1
# 4                         WHERE SHE GOES           Bad Bunny             1
# ..                                   ...                 ...           ...
# 948                         My Mind & Me        Selena Gomez             1
# 949            Bigger Than The Whole Sky        Taylor Swift             1
# 950                 A Veces (feat. Feid)  Feid, Paulo Londra             2
# 951                        En La De Ella  Feid, Sech, Jhayco             3
# 952                                Alone           Burna Boy             1
#
# ...

# %%
df['track_name'] #samo edna kolona
df
# Out:
#                               track_name      artist(s)_name  artist_count  \
# 0    Seven (feat. Latto) (Explicit Ver.)    Latto, Jung Kook             2
# 1                                   LALA         Myke Towers             1
# 2                                vampire      Olivia Rodrigo             1
# 3                           Cruel Summer        Taylor Swift             1
# 4                         WHERE SHE GOES           Bad Bunny             1
# ..                                   ...                 ...           ...
# 948                         My Mind & Me        Selena Gomez             1
# 949            Bigger Than The Whole Sky        Taylor Swift             1
# 950                 A Veces (feat. Feid)  Feid, Paulo Londra             2
# 951                        En La De Ella  Feid, Sech, Jhayco             3
# 952                                Alone           Burna Boy             1
#
# ...

# %%
columns_to_get = ['track_name', 'artist(s)_name','streams']
df_3col = df[columns_to_get]
df_3col
# Out:
#                               track_name      artist(s)_name    streams
# 0    Seven (feat. Latto) (Explicit Ver.)    Latto, Jung Kook  141381703
# 1                                   LALA         Myke Towers  133716286
# 2                                vampire      Olivia Rodrigo  140003974
# 3                           Cruel Summer        Taylor Swift  800840817
# 4                         WHERE SHE GOES           Bad Bunny  303236322
# ..                                   ...                 ...        ...
# 948                         My Mind & Me        Selena Gomez   91473363
# 949            Bigger Than The Whole Sky        Taylor Swift  121871870
# 950                 A Veces (feat. Feid)  Feid, Paulo Londra   73513683
# 951                        En La De Ella  Feid, Sech, Jhayco  133895612
# 952                                Alone           Burna Boy   96007391
#
# [953 rows x 3 columns]

# %%
#df['released_year'] ==2023
filter_year = df['released_year'] ==2023
df[filter_year]
# Out:
#                               track_name  \
# 0    Seven (feat. Latto) (Explicit Ver.)
# 1                                   LALA
# 2                                vampire
# 4                         WHERE SHE GOES
# 5                               Sprinter
# ..                                   ...
# 381         I'm Not Here To Make Friends
# 382                            TRUSTFALL
# 385            VIBE (feat. Jimin of BTS)
# 398                             Muï¿½ï¿½
# 404                      Sugar Rush Ride
#
#                              artist(s)_name  artist_count  released_year  \
# 0                          Latto, Jung Kook             2           2023
# 1                               Myke Towers             1           2023
# 2                            Olivia Rodrigo             1           2023
# 4                                 Bad Bunny             1           2023
# 5                         Dave, Central Cee             2           2023
# ...

# %%
filtered_df = df[
    (df['in_spotify_playlists']>=1500) & 
   (df['in_spotify_playlists']<=1800) & 
   (df['released_year'] ==2023)].copy()

# %%
df[((df['released_year'] ==2023) | (df['released_year'] ==2022)) &
   (df['in_spotify_playlists'] > 2000)
    ]

# %%
filtered_df.to_json('new_file.json',orient='records', index=False)
filtered_df
# Out:
#                                   track_name  \
# 131                                      OMG
# 260                      Never Felt So Alone
# 280  Watch This - ARIZONATEARS Pluggnb Remix
# 332               Tormenta (feat. Bad Bunny)
# 340                                   Heaven
#
#                                     artist(s)_name  artist_count  \
# 131                                       NewJeans             1
# 260                                       Labrinth             1
# 280  sped up nightcore, ARIZONATEARS, Lil Uzi Vert             3
# 332                            Gorillaz, Bad Bunny             2
# 340                                    Niall Horan             1
#
#      released_year  released_month  released_day  in_spotify_playlists  \
# 131           2023               1             2                  1783
# 260           2023               4             7                  1730
# 280           2023               2             5                  1638
# ...

# %%
new_df = pd.read_csv ('new_file.csv')
new_df
# Out:
#    Unnamed: 0                               track_name  \
# 0         131                                      OMG
# 1         260                      Never Felt So Alone
# 2         280  Watch This - ARIZONATEARS Pluggnb Remix
# 3         332               Tormenta (feat. Bad Bunny)
# 4         340                                   Heaven
#
#                                   artist(s)_name  artist_count  released_year  \
# 0                                       NewJeans             1           2023
# 1                                       Labrinth             1           2023
# 2  sped up nightcore, ARIZONATEARS, Lil Uzi Vert             3           2023
# 3                            Gorillaz, Bad Bunny             2           2023
# 4                                    Niall Horan             1           2023
#
#    released_month  released_day  in_spotify_playlists  in_spotify_charts  \
# 0               1             2                  1783                 27
# ...
