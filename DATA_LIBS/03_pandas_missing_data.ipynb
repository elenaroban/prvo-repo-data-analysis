# %%
import pandas as pd

# %%
df = pd.read_csv('complex_missing_data_real_names_dataset.csv')

# %%
df.head()
# Out:
#    ID           Name   Age   Salary Department    JoinDate PerformanceScore  \
# 0   1     John Smith  42.0  67744.0         IT  2015-01-31              NaN
# 1   2       Jane Doe  50.0      NaN      Sales  2015-02-28          Average
# 2   3  Emily Johnson  55.0  66187.0         HR  2015-03-31             Poor
# 3   4  Michael Brown  23.0  37239.0         HR  2015-04-30             Good
# 4   5    Sarah Davis  49.0  44489.0    Finance  2015-05-31          Average
#
#   Remote EducationLevel  YearsAtCompany
# 0   True            NaN             7.0
# 1  False       Bachelor             2.0
# 2  False    High School            13.0
# 3  False       Bachelor            13.0
# 4  False            NaN            12.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                100 non-null    int64
#  1   Name              100 non-null    object
#  2   Age               90 non-null     float64
#  3   Salary            85 non-null     float64
#  4   Department        95 non-null     object
#  5   JoinDate          100 non-null    object
#  6   PerformanceScore  90 non-null     object
#  7   Remote            95 non-null     object
#  8   EducationLevel    80 non-null     object
#  9   YearsAtCompany    90 non-null     float64
# dtypes: float64(3), int64(1), object(6)
# memory usage: 7.9+ KB

# %%
missing_data_df = df.isna()
# True = missing data
# False = there is data

# %%
missing_data_df.sum()
# Out:
# ID                   0
# Name                 0
# Age                 10
# Salary              15
# Department           5
# JoinDate             0
# PerformanceScore    10
# Remote               5
# EducationLevel      20
# YearsAtCompany      10
# dtype: int64

# %% [markdown]
# * default value
# * deleting data

# %% [markdown]
# # Default Value
#
# * Whole dataset
# * On column level

# %%
# whole dataseds
df.fillna(value=0,inplace=True)

# %%
df
# Out:
#      ID           Name   Age   Salary Department    JoinDate PerformanceScore  \
# 0     1     John Smith  42.0  67744.0         IT  2015-01-31                0
# 1     2       Jane Doe  50.0      0.0      Sales  2015-02-28          Average
# 2     3  Emily Johnson  55.0  66187.0         HR  2015-03-31             Poor
# 3     4  Michael Brown  23.0  37239.0         HR  2015-04-30             Good
# 4     5    Sarah Davis  49.0  44489.0    Finance  2015-05-31          Average
# ..  ...            ...   ...      ...        ...         ...              ...
# 95   96   Ariana James  26.0  40478.0          0  2022-12-31             Good
# 96   97     Eli Warren  18.0  85645.0    Finance  2023-01-31          Average
# 97   98   Addison Wood  30.0  49262.0    Finance  2023-02-28          Average
# 98   99  Joseph Barnes  21.0  82796.0         HR  2023-03-31             Good
# 99  100  Bella Jenkins  18.0      0.0         IT  2023-04-30             Good
#
# ...

# %%
df['Salary'].fillna(10000, inplace=True)
df['Department'].fillna('Unknown', inplace=True)
df['PerformanceScore'].fillna('Still in progress',inplace = True)
df['Age'].fillna(18, inplace=True)

# %%
df.isna().sum()
# Out:
# ID                   0
# Name                 0
# Age                  0
# Salary               0
# Department           0
# JoinDate             0
# PerformanceScore     0
# Remote               5
# EducationLevel      20
# YearsAtCompany      10
# dtype: int64

# %% [markdown]
# # Dropping data
#
# * Remove columns with missing data
# * Remove rows with missing data

# %%
df.dropna(inplace=True)

# %%
len(df)
# Out:
# 69

# %%
# axis 0 e red, 1 kolona
df.dropna(axis=1, inplace=True)

# %%
df
# Out:
#      ID           Name    JoinDate
# 0     1     John Smith  2015-01-31
# 1     2       Jane Doe  2015-02-28
# 2     3  Emily Johnson  2015-03-31
# 3     4  Michael Brown  2015-04-30
# 4     5    Sarah Davis  2015-05-31
# ..  ...            ...         ...
# 95   96   Ariana James  2022-12-31
# 96   97     Eli Warren  2023-01-31
# 97   98   Addison Wood  2023-02-28
# 98   99  Joseph Barnes  2023-03-31
# 99  100  Bella Jenkins  2023-04-30
#
# [100 rows x 3 columns]
