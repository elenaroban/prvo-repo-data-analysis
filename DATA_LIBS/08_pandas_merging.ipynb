# %%
import pandas as pd

# %%
df_clients = pd.read_csv("datasets/bank_clients.csv")
df_clients.head()
# Out:
#    ClientID FirstName     LastName    City   Balance
# 0         1   Gordana    Mitrevski  Bitola  33690.09
# 1         2   Dragana   Nikolovski  Bitola  44924.57
# 2         3     Elena  Georgievski  Prilep  26249.67
# 3         4   Gordana   Jovanovska  Bitola  10381.74
# 4         5    Cvetan    Mitrevski  Bitola  37096.02

# %%
df_accounts = pd.read_csv("datasets/bank_accounts.csv")
df_accounts.head()
# Out:
#    ClientID  AccountNumber AccountType    Branch  TransactionAmount
# 0        26     2734463155     Savings    Prilep             506.57
# 1        27     1278710077    Checking    Bitola            4048.33
# 2        28     2090558393      Credit    Skopje            4391.86
# 3        29     8285571366     Savings    Prilep            7466.02
# 4        30     8354146178     Savings  Kumanovo            2583.52

# %%
df_main = pd.merge(left=df_clients, right=df_accounts, how="right", on=["ClientID", "ClientID"])

# %%
df_main
# Out:
#     ClientID   FirstName     LastName      City   Balance  AccountNumber  \
# 0         26       Filip    Petrovski    Skopje  46836.39     2734463155
# 1         27       Filip   Jovanovska    Skopje  41365.42     1278710077
# 2         28       Bojan   Jovanovska    Skopje  33503.17     2090558393
# 3         29   Hristijan    Mitrevski    Skopje  44215.73     8285571366
# 4         30     Dragana   Jovanovska    Prilep  41165.24     8354146178
# 5         31       Elena    Mitrevski     Ohrid  13395.65     1636028516
# 6         32  Aleksandar   Jovanovska     Ohrid  45165.15     5285262775
# 7         33     Dragana     Ilievski    Skopje  29270.40     2145815738
# 8         34       Bojan   Angelovska     Ohrid  41334.81     5194529281
# 9         35       Filip    Mitrevski     Ohrid  45324.11     7060357851
# 10        36       Elena  Georgievski    Skopje  19310.16     5436919126
# 11        37     Dragana   Nikolovski     Ohrid   9952.34     2482069727
# ...
